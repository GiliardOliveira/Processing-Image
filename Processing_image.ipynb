# %% [markdown]
# <a href="https://colab.research.google.com/github/GiliardOliveira/Processing-Image/blob/master/Processing_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
from skimage import data
import matplotlib.pyplot as plt
img = data.astronaut()
#Imagem de astronauta do scikit-images
plt.imshow(img)
plt.show()

# %%
from math import radians
import numpy as np
import matplotlib.pyplot as plt


def main():
    x = np.arange(0, radians(1800), radians(12))
    plt.plot(x, np.cos(x), 'b')
    plt.show()

main()

# %%
import PIL

from PIL import Image, ImageDraw
image = Image.new("RGB",(500, 500), color =(0,0,0))
draw= ImageDraw.Draw(image)
draw.text((180,280), "Processamento de Imagem")
image.save("texto.png")

image
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7F433E54F518>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from skimage import data
from skimage.color import rgb2gray
original = data.astronaut()
grayscale = rgb2gray(original)

fig, axes = plt.subplots(1,2,figsize=(8,4))
ax= axes.ravel()


ax[0].imshow(original)
ax[0].set_title("Original")
ax[1].imshow(grayscale,cmap=plt.cm.gray)
ax[1].set_title("Grayscale")

fig.tight_layout()
plt.show()

# %%
#converter em preto e branco.

# %%
import cv2
from google.colab.patches import cv2_imshow
imagem = cv2.imread('whatsapp-icone-1.png')
print('Largura px= ', end='')
print(imagem.shape[1])
print('altura px= ', end='')
print(imagem.shape[0])
print('canais = ', end='')
print(imagem.shape[2])

cv2_imshow(imagem)
cv2.waitKey(0)
cv2.imwrite("saida.jpg",imagem)
# Out:
# Largura px= 2100
# altura px= 2109
# canais = 3
# <PIL.Image.Image image mode=RGB size=2100x2109 at 0x7F433076BC88>
# True

# %%
# %matplotlib inline
from skimage import data
import numpy as np
img = data.astronaut()
print(img[450,150])
# Out:
# [190  66  19]

# %%
import cv2
img = cv2.imread('ponte.jpg')
(b,g,r)= img[0,0]
print('o pixel (0,0) tem as cores')
print('R', r, 'G', g, 'B',b)
# Out:
# o pixel (0,0) tem as cores
# R 73 G 91 B 93

# %%
import cv2
img = cv2.imread('ponte.jpg')
for y in range (0,img.shape[0]):
    for x in range(0,img.shape[1]):
      img[y,x] = (255,0,0)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=639x361 at 0x7F43281A1A58>

# %%
import cv2
img = cv2.imread('ponte.jpg')
for y in range (0,img.shape[0],1):
    for x in range(0,img.shape[1],1):
      img[y,x] = (0,(x*y)%256,0)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=639x361 at 0x7F43281B7FD0>

# %%
import cv2
img = cv2.imread('ponte.jpg')
for y in range (0,img.shape[0]):
    for x in range(0,img.shape[1]):
      img[y,x] = (0,y%256,0)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=639x361 at 0x7F43281B4320>

# %%
import cv2
img = cv2.imread('ponte.jpg')
for y in range(0,img.shape[0],10):
  for x in range(0,img.shape[1],10):
    img[y:y+5,x:x+5] = (0,0,255)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=639x361 at 0x7F43281B4860>
